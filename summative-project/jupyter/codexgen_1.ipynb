# %% [markdown]
# # Human Resources Dataset Exploration
#
# Notes derived from `README.md`:
# - The dataset (`HR_comma_sep.csv`) contains 14,999 rows and 10 columns with no missing values.
# - Columns include satisfaction levels, evaluations, project counts, monthly hours, tenure, accidents, turnover (`left`), promotions, department (`sales`), and salary band.
# - Data is CC0 public domain and suited for descriptive analysis and attrition prediction.
#
# The cells below load the CSV from `../input/HR_comma_sep.csv`, inspect its schema, and preview a few rows.

# %%
from pathlib import Path
import pandas as pd

data_path = Path("../input/HR_source.csv")
if not data_path.exists():
    raise FileNotFoundError(f"Expected to find {data_path} next to this notebook.")

df = pd.read_csv(data_path)
df.shape

# %%
df.head()

# %%
df.describe(include='all').transpose()
